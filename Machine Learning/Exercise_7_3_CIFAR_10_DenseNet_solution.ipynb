# %% [markdown]
# <a href="https://colab.research.google.com/github/elariekerboull/master_uppsala/blob/main/Machine%20Learning/Exercise_7_3_CIFAR_10_DenseNet_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from keras.models import Model
from keras.layers import (
    Input,  # we inport the layers directly to save some space later.
    Dense,
    Dropout,
    Activation,
    Convolution2D,
    AveragePooling2D,
    GlobalAveragePooling2D,
    concatenate)
from keras.regularizers import l2
import matplotlib.pyplot as plt
from tabulate import tabulate
layers = tf.keras.layers

# %% [markdown]
# The following functions define the DenseNet architecture. It uses a different way to use the KERAS API where the output of each layer is explicitely passed to the next layer. This allows to stack together (concacenate) the outputs from multiple layers.
#
# Consider this simple example
# ```
# x = Conv2D(10, (2,2), paddig="same")
# y = Conv2D(10, 2,2), paddig="same")
# z = concatenate(x, y)
# ...
# ```
# Here, the output of the first convolution layer is combined with the result from the second convolution layer.

# %%
def conv_block(x, filters, drop=0, decay=1E-4, name='conv'):
    """ Apply BatchNorm, ReLU, Conv2D and (optionally) Dropout.

    # Arguments
        x: Input Keras tensor
        filters: number of convolution filters
        drop: dropout fraction
        decay: weight decay factor

    # Returns
        Keras tensor after the convolution block.
    """

    x = Convolution2D(filters, (3, 3),
                      padding='same',
                      use_bias=False,
                      kernel_initializer='he_uniform',
                      kernel_regularizer=l2(decay),
                      name=name + '_conv2D')(x)
    x = Activation('relu', name=name + '_relu')(x)
    if drop:
        x = Dropout(drop)(x)
    return x


def dense_block(x, num_layers, filters, drop=0, decay=1E-4, name='dense'):
    """ Build a dense_block where each layer is connected to all subsequent layers.

    # Arguments
        x: Keras tensor
        num_layers: the number of convolution_layers in the dense block
        filters: number of extra filters in each subsequent convolution
        drop: dropout fraction
        decay: weight decay factor

    # Returns:
        Keras tensor after the dense block.
    """
    xl = [x]
    for i in range(num_layers):
        _name = '%s_%i' % (name, i + 1)
        x = conv_block(x, filters, drop=drop, decay=decay, name=_name)
        xl.append(x)
        x = concatenate(xl[:], axis=-1, name=_name + '_concat')
    return x


def transition_block(x, filters, drop=None, decay=1E-4, name='transition'):
    """ Apply BatchNorm, ReLU, 1x1 Conv2D, Dropout and Maxpooling2D

    # Arguments
        x: Keras tensor
        filters: number of filters
        drop: dropout fraction
        decay: weight decay factor

    # Returns
        Keras tensor after the transition block
    """

    x = Convolution2D(int(filters), (1, 1),
                      padding='same',
                      use_bias=False,
                      kernel_initializer='he_uniform',
                      kernel_regularizer=l2(decay),
                      name=name + '_1x1conv')(x)
    x = Activation('relu', name=name + '_relu')(x)
    if drop:
        x = Dropout(drop)(x)
    x = AveragePooling2D((2, 2), strides=(2, 2), name=name + '_2x2pooling')(x)
    return x


def DenseNet(
        input_shape=(32, 32, 3),
        num_classes=10,
        dense=3,
        layers=12,
        growth=12,
        filters=16,
        bottleneck=False,
        compression=1,
        drop=0,
        decay=1E-4):
    """
    Build the DenseNet model

    # Arguments
        input_shape: tuple of shape (channels, rows, columns) or (rows, columns, channels)
        num_classes: number of classes
        dense: number of dense blocks (default 3)
        layers: number of convolution layers per dense block
        growth: number of filters k to add per convolution
        filters: initial number of filters (default 16)
        bottleneck: not implemented
        compression: compression factor of transition blocks (0 - 1)
        drop: dropout fraction
        decay: weight decay

    # Returns
        A Keras model
    """
    x0 = Input(shape=input_shape, name='input')

    # initial convolution
    x = Convolution2D(filters, (3, 3),
                      padding='same',
                      use_bias=False,
                      kernel_initializer='he_uniform',
                      kernel_regularizer=l2(decay),
                      name="initial_conv")(x0)
    x = Activation('relu', name='init_relu')(x)

    for i in range(dense):
        # add dense block
        x = dense_block(x, layers, growth,
                        drop=drop,
                        decay=decay,
                        name='dense_%i' % (i + 1))

        # update the number of filters
        filters += layers * growth
        filters = int(filters * compression)

        # add transition_block, except after last dense_block
        if i < (dense - 1):
            x = transition_block(x, filters,
                                 drop=drop,
                                 decay=decay,
                                 name='transition_%i' % (i + 1))

    x = GlobalAveragePooling2D(name='final_globalpooling')(x)

    # classification layer
    x = Dense(num_classes,
              kernel_regularizer=l2(decay),
              bias_regularizer=l2(decay),
              activation='softmax',
              name='classification')(x)

    return Model(inputs=[x0], outputs=[x], name='DenseNet')

# %%
def plot_examples(X, Y, n=10):
    """ Plot the first n examples for each of the 10 classes in the CIFAR dataset X, Y """
    fig, axes = plt.subplots(n, 10, figsize=(10, n))
    for l in range(10):
        axes[0, l].set_title(cifar10_labels[l], fontsize="smaller")
        m = np.squeeze(Y) == l  # boolean mask: True for all images of label l
        for i in range(n):
            image = X[m][i].astype("uint8")  # imshow expects uint8
            ax = axes[i, l]
            ax.imshow(image, origin="upper")
            ax.set(xticks=[], yticks=[])
    return fig, ax


def plot_prediction(X, Y, Y_predict):
    """
    Plot image X along with predicted probabilities Y_predict.
    X: CIFAR image, shape = (32, 32, 3)
    Y: CIFAR label, one-hot encoded, shape = (10)
    Y_predict: predicted probabilities, shape = (10)
    """
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4))

    # plot image
    ax1.imshow(X.astype("uint8"), origin="upper")
    ax1.set(xticks=[], yticks=[])

    # plot probabilities
    ax2.barh(np.arange(10), Y_predict, align="center")
    ax2.set(xlim=(0, 1), xlabel="Score", yticks=[])
    for i in range(10):
        c = "red" if (i == np.argmax(Y)) else "black"
        ax2.text(0.05, i, cifar10_labels[i].capitalize(), ha="left", va="center", color=c)



def plot_confusion(Y_true, Y_predict):
    """
    Plot confusion matrix
    Y_true:    array of true classifications (0-9), shape = (N)
    Y_predict: array of predicted classifications (0-9), shape = (N)
    """
    C = np.histogram2d(Y_true, Y_predict, bins=np.linspace(-0.5, 9.5, 11))[0]
    Cn = C / np.sum(C, axis=1)

    fig = plt.figure()
    plt.imshow(Cn, interpolation="nearest", vmin=0, vmax=1, cmap=plt.cm.YlGnBu)
    plt.colorbar()
    plt.xlabel("prediction")
    plt.ylabel("truth")
    plt.xticks(range(10), cifar10_labels, rotation="vertical")
    plt.yticks(range(10), cifar10_labels)
    for x in range(10):
        for y in range(10):
            plt.annotate("%i" % C[x, y], xy=(y, x), ha="center", va="center")

# %% [markdown]
# First we load and preprocess CIFAR-10 data. The imagages are 32x32 pixels and have three color channels (red, green, blue).

# %%
# X: images, Y: labels
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

print("images, shape = ", x_train.shape)
print("labels, shape = ", y_train.shape)

cifar10_labels = np.array([
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck'])


def normalize(images):
    mean = np.mean(images, axis=0)[np.newaxis]  # shape = (1, 32, 32, 3)
    sigma = np.std(images, axis=0)[np.newaxis]  # shape = (1, 32, 32, 3)
    images_normalized = (images - mean) / sigma
    return images_normalized

# normalize each pixel and color-channel separately across all images
# take 2000 images for validation from test data
x_train_norm = normalize(x_train)
x_test_norm = normalize(x_test)[:8000]
x_valid_norm = normalize(x_test)[8000:]

# convert labels ("0"-"9") to one-hot encodings, "0" = (1, 0, ... 0) and so on
y_train_onehot = tf.keras.utils.to_categorical(y_train, 10)
y_test_onehot = tf.keras.utils.to_categorical(y_test, 10)[:8000]
y_valid_onehot = tf.keras.utils.to_categorical(y_test, 10)[8000:]
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step
# images, shape =  (50000, 32, 32, 3)
# labels, shape =  (50000, 1)

# %% [markdown]
# We start with a fully connected network

# %%
# ----------------------------------------------------------
# Define model
# ----------------------------------------------------------
model = DenseNet()

print(model.summary())
# Out:
# Model: "DenseNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# initial_conv (Conv2D)           (None, 32, 32, 16)   432         input[0][0]
# __________________________________________________________________________________________________
# init_relu (Activation)          (None, 32, 32, 16)   0           initial_conv[0][0]
# __________________________________________________________________________________________________
# dense_1_1_conv2D (Conv2D)       (None, 32, 32, 12)   1728        init_relu[0][0]
# __________________________________________________________________________________________________
# dense_1_1_relu (Activation)     (None, 32, 32, 12)   0           dense_1_1_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_1_concat (Concatenate)  (None, 32, 32, 28)   0           init_relu[0][0]
#                                                                  dense_1_1_relu[0][0]
# __________________________________________________________________________________________________
# dense_1_2_conv2D (Conv2D)       (None, 32, 32, 12)   3024        dense_1_1_concat[0][0]
# __________________________________________________________________________________________________
# dense_1_2_relu (Activation)     (None, 32, 32, 12)   0           dense_1_2_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_2_concat (Concatenate)  (None, 32, 32, 40)   0           init_relu[0][0]
#                                                                  dense_1_1_relu[0][0]
#                                                                  dense_1_2_relu[0][0]
# __________________________________________________________________________________________________
# dense_1_3_conv2D (Conv2D)       (None, 32, 32, 12)   4320        dense_1_2_concat[0][0]
# __________________________________________________________________________________________________
# dense_1_3_relu (Activation)     (None, 32, 32, 12)   0           dense_1_3_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_3_concat (Concatenate)  (None, 32, 32, 52)   0           init_relu[0][0]
#                                                                  dense_1_1_relu[0][0]
#                                                                  dense_1_2_relu[0][0]
#                                                                  dense_1_3_relu[0][0]
# __________________________________________________________________________________________________
# dense_1_4_conv2D (Conv2D)       (None, 32, 32, 12)   5616        dense_1_3_concat[0][0]
# __________________________________________________________________________________________________
# dense_1_4_relu (Activation)     (None, 32, 32, 12)   0           dense_1_4_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_4_concat (Concatenate)  (None, 32, 32, 64)   0           init_relu[0][0]
#                                                                  dense_1_1_relu[0][0]
#                                                                  dense_1_2_relu[0][0]
#                                                                  dense_1_3_relu[0][0]
#                                                                  dense_1_4_relu[0][0]
# __________________________________________________________________________________________________
# dense_1_5_conv2D (Conv2D)       (None, 32, 32, 12)   6912        dense_1_4_concat[0][0]
# __________________________________________________________________________________________________
# dense_1_5_relu (Activation)     (None, 32, 32, 12)   0           dense_1_5_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_5_concat (Concatenate)  (None, 32, 32, 76)   0           init_relu[0][0]
#                                                                  dense_1_1_relu[0][0]
#                                                                  dense_1_2_relu[0][0]
#                                                                  dense_1_3_relu[0][0]
#                                                                  dense_1_4_relu[0][0]
#                                                                  dense_1_5_relu[0][0]
# __________________________________________________________________________________________________
# dense_1_6_conv2D (Conv2D)       (None, 32, 32, 12)   8208        dense_1_5_concat[0][0]
# __________________________________________________________________________________________________
# dense_1_6_relu (Activation)     (None, 32, 32, 12)   0           dense_1_6_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_6_concat (Concatenate)  (None, 32, 32, 88)   0           init_relu[0][0]
#                                                                  dense_1_1_relu[0][0]
#                                                                  dense_1_2_relu[0][0]
#                                                                  dense_1_3_relu[0][0]
#                                                                  dense_1_4_relu[0][0]
#                                                                  dense_1_5_relu[0][0]
#                                                                  dense_1_6_relu[0][0]
# __________________________________________________________________________________________________
# dense_1_7_conv2D (Conv2D)       (None, 32, 32, 12)   9504        dense_1_6_concat[0][0]
# __________________________________________________________________________________________________
# dense_1_7_relu (Activation)     (None, 32, 32, 12)   0           dense_1_7_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_7_concat (Concatenate)  (None, 32, 32, 100)  0           init_relu[0][0]
#                                                                  dense_1_1_relu[0][0]
#                                                                  dense_1_2_relu[0][0]
#                                                                  dense_1_3_relu[0][0]
#                                                                  dense_1_4_relu[0][0]
#                                                                  dense_1_5_relu[0][0]
#                                                                  dense_1_6_relu[0][0]
#                                                                  dense_1_7_relu[0][0]
# __________________________________________________________________________________________________
# dense_1_8_conv2D (Conv2D)       (None, 32, 32, 12)   10800       dense_1_7_concat[0][0]
# __________________________________________________________________________________________________
# dense_1_8_relu (Activation)     (None, 32, 32, 12)   0           dense_1_8_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_8_concat (Concatenate)  (None, 32, 32, 112)  0           init_relu[0][0]
#                                                                  dense_1_1_relu[0][0]
#                                                                  dense_1_2_relu[0][0]
#                                                                  dense_1_3_relu[0][0]
#                                                                  dense_1_4_relu[0][0]
#                                                                  dense_1_5_relu[0][0]
#                                                                  dense_1_6_relu[0][0]
#                                                                  dense_1_7_relu[0][0]
#                                                                  dense_1_8_relu[0][0]
# __________________________________________________________________________________________________
# dense_1_9_conv2D (Conv2D)       (None, 32, 32, 12)   12096       dense_1_8_concat[0][0]
# __________________________________________________________________________________________________
# dense_1_9_relu (Activation)     (None, 32, 32, 12)   0           dense_1_9_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_9_concat (Concatenate)  (None, 32, 32, 124)  0           init_relu[0][0]
#                                                                  dense_1_1_relu[0][0]
#                                                                  dense_1_2_relu[0][0]
#                                                                  dense_1_3_relu[0][0]
#                                                                  dense_1_4_relu[0][0]
#                                                                  dense_1_5_relu[0][0]
#                                                                  dense_1_6_relu[0][0]
#                                                                  dense_1_7_relu[0][0]
#                                                                  dense_1_8_relu[0][0]
#                                                                  dense_1_9_relu[0][0]
# __________________________________________________________________________________________________
# dense_1_10_conv2D (Conv2D)      (None, 32, 32, 12)   13392       dense_1_9_concat[0][0]
# __________________________________________________________________________________________________
# dense_1_10_relu (Activation)    (None, 32, 32, 12)   0           dense_1_10_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_10_concat (Concatenate) (None, 32, 32, 136)  0           init_relu[0][0]
#                                                                  dense_1_1_relu[0][0]
#                                                                  dense_1_2_relu[0][0]
#                                                                  dense_1_3_relu[0][0]
#                                                                  dense_1_4_relu[0][0]
#                                                                  dense_1_5_relu[0][0]
#                                                                  dense_1_6_relu[0][0]
#                                                                  dense_1_7_relu[0][0]
#                                                                  dense_1_8_relu[0][0]
#                                                                  dense_1_9_relu[0][0]
#                                                                  dense_1_10_relu[0][0]
# __________________________________________________________________________________________________
# dense_1_11_conv2D (Conv2D)      (None, 32, 32, 12)   14688       dense_1_10_concat[0][0]
# __________________________________________________________________________________________________
# dense_1_11_relu (Activation)    (None, 32, 32, 12)   0           dense_1_11_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_11_concat (Concatenate) (None, 32, 32, 148)  0           init_relu[0][0]
#                                                                  dense_1_1_relu[0][0]
#                                                                  dense_1_2_relu[0][0]
#                                                                  dense_1_3_relu[0][0]
#                                                                  dense_1_4_relu[0][0]
#                                                                  dense_1_5_relu[0][0]
#                                                                  dense_1_6_relu[0][0]
#                                                                  dense_1_7_relu[0][0]
#                                                                  dense_1_8_relu[0][0]
#                                                                  dense_1_9_relu[0][0]
#                                                                  dense_1_10_relu[0][0]
#                                                                  dense_1_11_relu[0][0]
# __________________________________________________________________________________________________
# dense_1_12_conv2D (Conv2D)      (None, 32, 32, 12)   15984       dense_1_11_concat[0][0]
# __________________________________________________________________________________________________
# dense_1_12_relu (Activation)    (None, 32, 32, 12)   0           dense_1_12_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_12_concat (Concatenate) (None, 32, 32, 160)  0           init_relu[0][0]
#                                                                  dense_1_1_relu[0][0]
#                                                                  dense_1_2_relu[0][0]
#                                                                  dense_1_3_relu[0][0]
#                                                                  dense_1_4_relu[0][0]
#                                                                  dense_1_5_relu[0][0]
#                                                                  dense_1_6_relu[0][0]
#                                                                  dense_1_7_relu[0][0]
#                                                                  dense_1_8_relu[0][0]
#                                                                  dense_1_9_relu[0][0]
#                                                                  dense_1_10_relu[0][0]
#                                                                  dense_1_11_relu[0][0]
#                                                                  dense_1_12_relu[0][0]
# __________________________________________________________________________________________________
# transition_1_1x1conv (Conv2D)   (None, 32, 32, 160)  25600       dense_1_12_concat[0][0]
# __________________________________________________________________________________________________
# transition_1_relu (Activation)  (None, 32, 32, 160)  0           transition_1_1x1conv[0][0]
# __________________________________________________________________________________________________
# transition_1_2x2pooling (Averag (None, 16, 16, 160)  0           transition_1_relu[0][0]
# __________________________________________________________________________________________________
# dense_2_1_conv2D (Conv2D)       (None, 16, 16, 12)   17280       transition_1_2x2pooling[0][0]
# __________________________________________________________________________________________________
# dense_2_1_relu (Activation)     (None, 16, 16, 12)   0           dense_2_1_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_1_concat (Concatenate)  (None, 16, 16, 172)  0           transition_1_2x2pooling[0][0]
#                                                                  dense_2_1_relu[0][0]
# __________________________________________________________________________________________________
# dense_2_2_conv2D (Conv2D)       (None, 16, 16, 12)   18576       dense_2_1_concat[0][0]
# __________________________________________________________________________________________________
# dense_2_2_relu (Activation)     (None, 16, 16, 12)   0           dense_2_2_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_2_concat (Concatenate)  (None, 16, 16, 184)  0           transition_1_2x2pooling[0][0]
#                                                                  dense_2_1_relu[0][0]
#                                                                  dense_2_2_relu[0][0]
# __________________________________________________________________________________________________
# dense_2_3_conv2D (Conv2D)       (None, 16, 16, 12)   19872       dense_2_2_concat[0][0]
# __________________________________________________________________________________________________
# dense_2_3_relu (Activation)     (None, 16, 16, 12)   0           dense_2_3_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_3_concat (Concatenate)  (None, 16, 16, 196)  0           transition_1_2x2pooling[0][0]
#                                                                  dense_2_1_relu[0][0]
#                                                                  dense_2_2_relu[0][0]
#                                                                  dense_2_3_relu[0][0]
# __________________________________________________________________________________________________
# dense_2_4_conv2D (Conv2D)       (None, 16, 16, 12)   21168       dense_2_3_concat[0][0]
# __________________________________________________________________________________________________
# dense_2_4_relu (Activation)     (None, 16, 16, 12)   0           dense_2_4_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_4_concat (Concatenate)  (None, 16, 16, 208)  0           transition_1_2x2pooling[0][0]
#                                                                  dense_2_1_relu[0][0]
#                                                                  dense_2_2_relu[0][0]
#                                                                  dense_2_3_relu[0][0]
#                                                                  dense_2_4_relu[0][0]
# __________________________________________________________________________________________________
# dense_2_5_conv2D (Conv2D)       (None, 16, 16, 12)   22464       dense_2_4_concat[0][0]
# __________________________________________________________________________________________________
# dense_2_5_relu (Activation)     (None, 16, 16, 12)   0           dense_2_5_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_5_concat (Concatenate)  (None, 16, 16, 220)  0           transition_1_2x2pooling[0][0]
#                                                                  dense_2_1_relu[0][0]
#                                                                  dense_2_2_relu[0][0]
#                                                                  dense_2_3_relu[0][0]
#                                                                  dense_2_4_relu[0][0]
#                                                                  dense_2_5_relu[0][0]
# __________________________________________________________________________________________________
# dense_2_6_conv2D (Conv2D)       (None, 16, 16, 12)   23760       dense_2_5_concat[0][0]
# __________________________________________________________________________________________________
# dense_2_6_relu (Activation)     (None, 16, 16, 12)   0           dense_2_6_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_6_concat (Concatenate)  (None, 16, 16, 232)  0           transition_1_2x2pooling[0][0]
#                                                                  dense_2_1_relu[0][0]
#                                                                  dense_2_2_relu[0][0]
#                                                                  dense_2_3_relu[0][0]
#                                                                  dense_2_4_relu[0][0]
#                                                                  dense_2_5_relu[0][0]
#                                                                  dense_2_6_relu[0][0]
# __________________________________________________________________________________________________
# dense_2_7_conv2D (Conv2D)       (None, 16, 16, 12)   25056       dense_2_6_concat[0][0]
# __________________________________________________________________________________________________
# dense_2_7_relu (Activation)     (None, 16, 16, 12)   0           dense_2_7_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_7_concat (Concatenate)  (None, 16, 16, 244)  0           transition_1_2x2pooling[0][0]
#                                                                  dense_2_1_relu[0][0]
#                                                                  dense_2_2_relu[0][0]
#                                                                  dense_2_3_relu[0][0]
#                                                                  dense_2_4_relu[0][0]
#                                                                  dense_2_5_relu[0][0]
#                                                                  dense_2_6_relu[0][0]
#                                                                  dense_2_7_relu[0][0]
# __________________________________________________________________________________________________
# dense_2_8_conv2D (Conv2D)       (None, 16, 16, 12)   26352       dense_2_7_concat[0][0]
# __________________________________________________________________________________________________
# dense_2_8_relu (Activation)     (None, 16, 16, 12)   0           dense_2_8_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_8_concat (Concatenate)  (None, 16, 16, 256)  0           transition_1_2x2pooling[0][0]
#                                                                  dense_2_1_relu[0][0]
#                                                                  dense_2_2_relu[0][0]
#                                                                  dense_2_3_relu[0][0]
#                                                                  dense_2_4_relu[0][0]
#                                                                  dense_2_5_relu[0][0]
#                                                                  dense_2_6_relu[0][0]
#                                                                  dense_2_7_relu[0][0]
#                                                                  dense_2_8_relu[0][0]
# __________________________________________________________________________________________________
# dense_2_9_conv2D (Conv2D)       (None, 16, 16, 12)   27648       dense_2_8_concat[0][0]
# __________________________________________________________________________________________________
# dense_2_9_relu (Activation)     (None, 16, 16, 12)   0           dense_2_9_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_9_concat (Concatenate)  (None, 16, 16, 268)  0           transition_1_2x2pooling[0][0]
#                                                                  dense_2_1_relu[0][0]
#                                                                  dense_2_2_relu[0][0]
#                                                                  dense_2_3_relu[0][0]
#                                                                  dense_2_4_relu[0][0]
#                                                                  dense_2_5_relu[0][0]
#                                                                  dense_2_6_relu[0][0]
#                                                                  dense_2_7_relu[0][0]
#                                                                  dense_2_8_relu[0][0]
#                                                                  dense_2_9_relu[0][0]
# __________________________________________________________________________________________________
# dense_2_10_conv2D (Conv2D)      (None, 16, 16, 12)   28944       dense_2_9_concat[0][0]
# __________________________________________________________________________________________________
# dense_2_10_relu (Activation)    (None, 16, 16, 12)   0           dense_2_10_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_10_concat (Concatenate) (None, 16, 16, 280)  0           transition_1_2x2pooling[0][0]
#                                                                  dense_2_1_relu[0][0]
#                                                                  dense_2_2_relu[0][0]
#                                                                  dense_2_3_relu[0][0]
#                                                                  dense_2_4_relu[0][0]
#                                                                  dense_2_5_relu[0][0]
#                                                                  dense_2_6_relu[0][0]
#                                                                  dense_2_7_relu[0][0]
#                                                                  dense_2_8_relu[0][0]
#                                                                  dense_2_9_relu[0][0]
#                                                                  dense_2_10_relu[0][0]
# __________________________________________________________________________________________________
# dense_2_11_conv2D (Conv2D)      (None, 16, 16, 12)   30240       dense_2_10_concat[0][0]
# __________________________________________________________________________________________________
# dense_2_11_relu (Activation)    (None, 16, 16, 12)   0           dense_2_11_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_11_concat (Concatenate) (None, 16, 16, 292)  0           transition_1_2x2pooling[0][0]
#                                                                  dense_2_1_relu[0][0]
#                                                                  dense_2_2_relu[0][0]
#                                                                  dense_2_3_relu[0][0]
#                                                                  dense_2_4_relu[0][0]
#                                                                  dense_2_5_relu[0][0]
#                                                                  dense_2_6_relu[0][0]
#                                                                  dense_2_7_relu[0][0]
#                                                                  dense_2_8_relu[0][0]
#                                                                  dense_2_9_relu[0][0]
#                                                                  dense_2_10_relu[0][0]
#                                                                  dense_2_11_relu[0][0]
# __________________________________________________________________________________________________
# dense_2_12_conv2D (Conv2D)      (None, 16, 16, 12)   31536       dense_2_11_concat[0][0]
# __________________________________________________________________________________________________
# dense_2_12_relu (Activation)    (None, 16, 16, 12)   0           dense_2_12_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_12_concat (Concatenate) (None, 16, 16, 304)  0           transition_1_2x2pooling[0][0]
#                                                                  dense_2_1_relu[0][0]
#                                                                  dense_2_2_relu[0][0]
#                                                                  dense_2_3_relu[0][0]
#                                                                  dense_2_4_relu[0][0]
#                                                                  dense_2_5_relu[0][0]
#                                                                  dense_2_6_relu[0][0]
#                                                                  dense_2_7_relu[0][0]
#                                                                  dense_2_8_relu[0][0]
#                                                                  dense_2_9_relu[0][0]
#                                                                  dense_2_10_relu[0][0]
#                                                                  dense_2_11_relu[0][0]
#                                                                  dense_2_12_relu[0][0]
# __________________________________________________________________________________________________
# transition_2_1x1conv (Conv2D)   (None, 16, 16, 304)  92416       dense_2_12_concat[0][0]
# __________________________________________________________________________________________________
# transition_2_relu (Activation)  (None, 16, 16, 304)  0           transition_2_1x1conv[0][0]
# __________________________________________________________________________________________________
# transition_2_2x2pooling (Averag (None, 8, 8, 304)    0           transition_2_relu[0][0]
# __________________________________________________________________________________________________
# dense_3_1_conv2D (Conv2D)       (None, 8, 8, 12)     32832       transition_2_2x2pooling[0][0]
# __________________________________________________________________________________________________
# dense_3_1_relu (Activation)     (None, 8, 8, 12)     0           dense_3_1_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_3_1_concat (Concatenate)  (None, 8, 8, 316)    0           transition_2_2x2pooling[0][0]
#                                                                  dense_3_1_relu[0][0]
# __________________________________________________________________________________________________
# dense_3_2_conv2D (Conv2D)       (None, 8, 8, 12)     34128       dense_3_1_concat[0][0]
# __________________________________________________________________________________________________
# dense_3_2_relu (Activation)     (None, 8, 8, 12)     0           dense_3_2_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_3_2_concat (Concatenate)  (None, 8, 8, 328)    0           transition_2_2x2pooling[0][0]
#                                                                  dense_3_1_relu[0][0]
#                                                                  dense_3_2_relu[0][0]
# __________________________________________________________________________________________________
# dense_3_3_conv2D (Conv2D)       (None, 8, 8, 12)     35424       dense_3_2_concat[0][0]
# __________________________________________________________________________________________________
# dense_3_3_relu (Activation)     (None, 8, 8, 12)     0           dense_3_3_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_3_3_concat (Concatenate)  (None, 8, 8, 340)    0           transition_2_2x2pooling[0][0]
#                                                                  dense_3_1_relu[0][0]
#                                                                  dense_3_2_relu[0][0]
#                                                                  dense_3_3_relu[0][0]
# __________________________________________________________________________________________________
# dense_3_4_conv2D (Conv2D)       (None, 8, 8, 12)     36720       dense_3_3_concat[0][0]
# __________________________________________________________________________________________________
# dense_3_4_relu (Activation)     (None, 8, 8, 12)     0           dense_3_4_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_3_4_concat (Concatenate)  (None, 8, 8, 352)    0           transition_2_2x2pooling[0][0]
#                                                                  dense_3_1_relu[0][0]
#                                                                  dense_3_2_relu[0][0]
#                                                                  dense_3_3_relu[0][0]
#                                                                  dense_3_4_relu[0][0]
# __________________________________________________________________________________________________
# dense_3_5_conv2D (Conv2D)       (None, 8, 8, 12)     38016       dense_3_4_concat[0][0]
# __________________________________________________________________________________________________
# dense_3_5_relu (Activation)     (None, 8, 8, 12)     0           dense_3_5_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_3_5_concat (Concatenate)  (None, 8, 8, 364)    0           transition_2_2x2pooling[0][0]
#                                                                  dense_3_1_relu[0][0]
#                                                                  dense_3_2_relu[0][0]
#                                                                  dense_3_3_relu[0][0]
#                                                                  dense_3_4_relu[0][0]
#                                                                  dense_3_5_relu[0][0]
# __________________________________________________________________________________________________
# dense_3_6_conv2D (Conv2D)       (None, 8, 8, 12)     39312       dense_3_5_concat[0][0]
# __________________________________________________________________________________________________
# dense_3_6_relu (Activation)     (None, 8, 8, 12)     0           dense_3_6_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_3_6_concat (Concatenate)  (None, 8, 8, 376)    0           transition_2_2x2pooling[0][0]
#                                                                  dense_3_1_relu[0][0]
#                                                                  dense_3_2_relu[0][0]
#                                                                  dense_3_3_relu[0][0]
#                                                                  dense_3_4_relu[0][0]
#                                                                  dense_3_5_relu[0][0]
#                                                                  dense_3_6_relu[0][0]
# __________________________________________________________________________________________________
# dense_3_7_conv2D (Conv2D)       (None, 8, 8, 12)     40608       dense_3_6_concat[0][0]
# __________________________________________________________________________________________________
# dense_3_7_relu (Activation)     (None, 8, 8, 12)     0           dense_3_7_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_3_7_concat (Concatenate)  (None, 8, 8, 388)    0           transition_2_2x2pooling[0][0]
#                                                                  dense_3_1_relu[0][0]
#                                                                  dense_3_2_relu[0][0]
#                                                                  dense_3_3_relu[0][0]
#                                                                  dense_3_4_relu[0][0]
#                                                                  dense_3_5_relu[0][0]
#                                                                  dense_3_6_relu[0][0]
#                                                                  dense_3_7_relu[0][0]
# __________________________________________________________________________________________________
# dense_3_8_conv2D (Conv2D)       (None, 8, 8, 12)     41904       dense_3_7_concat[0][0]
# __________________________________________________________________________________________________
# dense_3_8_relu (Activation)     (None, 8, 8, 12)     0           dense_3_8_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_3_8_concat (Concatenate)  (None, 8, 8, 400)    0           transition_2_2x2pooling[0][0]
#                                                                  dense_3_1_relu[0][0]
#                                                                  dense_3_2_relu[0][0]
#                                                                  dense_3_3_relu[0][0]
#                                                                  dense_3_4_relu[0][0]
#                                                                  dense_3_5_relu[0][0]
#                                                                  dense_3_6_relu[0][0]
#                                                                  dense_3_7_relu[0][0]
#                                                                  dense_3_8_relu[0][0]
# __________________________________________________________________________________________________
# dense_3_9_conv2D (Conv2D)       (None, 8, 8, 12)     43200       dense_3_8_concat[0][0]
# __________________________________________________________________________________________________
# dense_3_9_relu (Activation)     (None, 8, 8, 12)     0           dense_3_9_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_3_9_concat (Concatenate)  (None, 8, 8, 412)    0           transition_2_2x2pooling[0][0]
#                                                                  dense_3_1_relu[0][0]
#                                                                  dense_3_2_relu[0][0]
#                                                                  dense_3_3_relu[0][0]
#                                                                  dense_3_4_relu[0][0]
#                                                                  dense_3_5_relu[0][0]
#                                                                  dense_3_6_relu[0][0]
#                                                                  dense_3_7_relu[0][0]
#                                                                  dense_3_8_relu[0][0]
#                                                                  dense_3_9_relu[0][0]
# __________________________________________________________________________________________________
# dense_3_10_conv2D (Conv2D)      (None, 8, 8, 12)     44496       dense_3_9_concat[0][0]
# __________________________________________________________________________________________________
# dense_3_10_relu (Activation)    (None, 8, 8, 12)     0           dense_3_10_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_3_10_concat (Concatenate) (None, 8, 8, 424)    0           transition_2_2x2pooling[0][0]
#                                                                  dense_3_1_relu[0][0]
#                                                                  dense_3_2_relu[0][0]
#                                                                  dense_3_3_relu[0][0]
#                                                                  dense_3_4_relu[0][0]
#                                                                  dense_3_5_relu[0][0]
#                                                                  dense_3_6_relu[0][0]
#                                                                  dense_3_7_relu[0][0]
#                                                                  dense_3_8_relu[0][0]
#                                                                  dense_3_9_relu[0][0]
#                                                                  dense_3_10_relu[0][0]
# __________________________________________________________________________________________________
# dense_3_11_conv2D (Conv2D)      (None, 8, 8, 12)     45792       dense_3_10_concat[0][0]
# __________________________________________________________________________________________________
# dense_3_11_relu (Activation)    (None, 8, 8, 12)     0           dense_3_11_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_3_11_concat (Concatenate) (None, 8, 8, 436)    0           transition_2_2x2pooling[0][0]
#                                                                  dense_3_1_relu[0][0]
#                                                                  dense_3_2_relu[0][0]
#                                                                  dense_3_3_relu[0][0]
#                                                                  dense_3_4_relu[0][0]
#                                                                  dense_3_5_relu[0][0]
#                                                                  dense_3_6_relu[0][0]
#                                                                  dense_3_7_relu[0][0]
#                                                                  dense_3_8_relu[0][0]
#                                                                  dense_3_9_relu[0][0]
#                                                                  dense_3_10_relu[0][0]
#                                                                  dense_3_11_relu[0][0]
# __________________________________________________________________________________________________
# dense_3_12_conv2D (Conv2D)      (None, 8, 8, 12)     47088       dense_3_11_concat[0][0]
# __________________________________________________________________________________________________
# dense_3_12_relu (Activation)    (None, 8, 8, 12)     0           dense_3_12_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_3_12_concat (Concatenate) (None, 8, 8, 448)    0           transition_2_2x2pooling[0][0]
#                                                                  dense_3_1_relu[0][0]
#                                                                  dense_3_2_relu[0][0]
#                                                                  dense_3_3_relu[0][0]
#                                                                  dense_3_4_relu[0][0]
#                                                                  dense_3_5_relu[0][0]
#                                                                  dense_3_6_relu[0][0]
#                                                                  dense_3_7_relu[0][0]
#                                                                  dense_3_8_relu[0][0]
#                                                                  dense_3_9_relu[0][0]
#                                                                  dense_3_10_relu[0][0]
#                                                                  dense_3_11_relu[0][0]
#                                                                  dense_3_12_relu[0][0]
# __________________________________________________________________________________________________
# final_globalpooling (GlobalAver (None, 448)          0           dense_3_12_concat[0][0]
# __________________________________________________________________________________________________
# classification (Dense)          (None, 10)           4490        final_globalpooling[0][0]
# ==================================================================================================
# Total params: 1,001,626
# Trainable params: 1,001,626
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
# ----------------------------------------------------------
# Training
# ----------------------------------------------------------
model.compile(
    loss="categorical_crossentropy",
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    metrics=["accuracy"],
)

model.fit(
    x_train_norm,
    y_train_onehot,
    batch_size=32,
    epochs=20,
    verbose=1,
    validation_data=(x_valid_norm, y_valid_onehot),
    callbacks=[tf.keras.callbacks.CSVLogger("history_{}.csv".format(model.name))],
)
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 253s 139ms/step - loss: 1.7570 - accuracy: 0.3952 - val_loss: 1.4002 - val_accuracy: 0.5320
# Epoch 2/20
# 1563/1563 [==============================] - 214s 137ms/step - loss: 1.2730 - accuracy: 0.5867 - val_loss: 1.1343 - val_accuracy: 0.6410
# Epoch 3/20
# 1563/1563 [==============================] - 215s 137ms/step - loss: 1.0858 - accuracy: 0.6622 - val_loss: 1.1030 - val_accuracy: 0.6480
# Epoch 4/20
# 1563/1563 [==============================] - 215s 137ms/step - loss: 0.9877 - accuracy: 0.7005 - val_loss: 0.9874 - val_accuracy: 0.7010
# Epoch 5/20
# 1563/1563 [==============================] - 215s 137ms/step - loss: 0.9213 - accuracy: 0.7262 - val_loss: 0.8933 - val_accuracy: 0.7465
# Epoch 6/20
# 1563/1563 [==============================] - 214s 137ms/step - loss: 0.8598 - accuracy: 0.7511 - val_loss: 0.9041 - val_accuracy: 0.7380
# Epoch 7/20
# 1563/1563 [==============================] - 214s 137ms/step - loss: 0.8099 - accuracy: 0.7740 - val_loss: 0.8903 - val_accuracy: 0.7490
# Epoch 8/20
# 1563/1563 [==============================] - 214s 137ms/step - loss: 0.7740 - accuracy: 0.7877 - val_loss: 0.8148 - val_accuracy: 0.7810
# Epoch 9/20
# 1563/1563 [==============================] - 214s 137ms/step - loss: 0.7412 - accuracy: 0.8012 - val_loss: 0.7867 - val_accuracy: 0.7930
# Epoch 10/20
# 1563/1563 [==============================] - 214s 137ms/step - loss: 0.7154 - accuracy: 0.8108 - val_loss: 0.8321 - val_accuracy: 0.7765
# Epoch 11/20
# 1563/1563 [==============================] - 214s 137ms/step - loss: 0.6929 - accuracy: 0.8206 - val_loss: 0.8043 - val_accuracy: 0.7885
# Epoch 12/20
# 1563/1563 [==============================] - 214s 137ms/step - loss: 0.6733 - accuracy: 0.8287 - val_loss: 0.7625 - val_accuracy: 0.8055
# Epoch 13/20
# 1563/1563 [==============================] - 214s 137ms/step - loss: 0.6556 - accuracy: 0.8365 - val_loss: 0.7586 - val_accuracy: 0.7950
# Epoch 14/20
# 1563/1563 [==============================] - 214s 137ms/step - loss: 0.6346 - accuracy: 0.8432 - val_loss: 0.7438 - val_accuracy: 0.8110
# Epoch 15/20
# 1563/1563 [==============================] - 214s 137ms/step - loss: 0.6245 - accuracy: 0.8479 - val_loss: 0.7507 - val_accuracy: 0.8080
# Epoch 16/20
# 1563/1563 [==============================] - 214s 137ms/step - loss: 0.6159 - accuracy: 0.8524 - val_loss: 0.7615 - val_accuracy: 0.8010
# Epoch 17/20
# 1563/1563 [==============================] - 214s 137ms/step - loss: 0.6023 - accuracy: 0.8592 - val_loss: 0.7454 - val_accuracy: 0.8220
# Epoch 18/20
# 1563/1563 [==============================] - 214s 137ms/step - loss: 0.5899 - accuracy: 0.8624 - val_loss: 0.7403 - val_accuracy: 0.8220
# Epoch 19/20
# 1563/1563 [==============================] - 215s 137ms/step - loss: 0.5862 - accuracy: 0.8650 - val_loss: 0.7408 - val_accuracy: 0.8250
# Epoch 20/20
# 1563/1563 [==============================] - 214s 137ms/step - loss: 0.5723 - accuracy: 0.8723 - val_loss: 0.7284 - val_accuracy: 0.8250

# %%
print("Model performance :")
headers = ["", "Loss", "Accuracy"]

table = [
    ["Train", *model.evaluate(x_train_norm, y_train_onehot, verbose=0, batch_size=128)],
    ["Validation", *model.evaluate(x_valid_norm, y_valid_onehot, verbose=0, batch_size=128)],
    ["Test", *model.evaluate(x_test_norm, y_test_onehot, verbose=0, batch_size=128)],
]

print(tabulate(table, headers=headers, tablefmt="orgtbl"))
# Out:
# Model performance :
# |            |     Loss |   Accuracy |
# |------------+----------+------------|
# | Train      | 0.519521 |    0.89426 |
# | Validation | 0.728443 |    0.825   |
# | Test       | 0.744042 |    0.819   |

# %%
# ----------------------------------------------------------
# Plots
# ----------------------------------------------------------
# training curves
history = np.genfromtxt("history_{}.csv".format(model.name), delimiter=",", names=True)

fig, ax = plt.subplots(1)
ax.plot(history["epoch"], history["loss"], label="training")
ax.plot(history["epoch"], history["val_loss"], label="validation")
ax.legend()
ax.set(xlabel="epoch", ylabel="loss")

fig, ax = plt.subplots(1)
ax.plot(history["epoch"], history["accuracy"], label="training")
ax.plot(history["epoch"], history["val_accuracy"], label="validation")
ax.legend()
ax.set(xlabel="epoch", ylabel="accuracy")

# calculate predictions for test set
y_predict = model.predict(x_test_norm, batch_size=128)

# convert back to class labels (0-9)
y_predict_cl = np.argmax(y_predict, axis=1)
y_test_cl = np.argmax(y_test_onehot, axis=1)

# plot confusion matrix
plot_confusion(
    y_test_cl, y_predict_cl
)

# compare prediction and truth
m = y_predict_cl == y_test_cl
i0 = np.arange(8000)[~m]  # misclassified images
i1 = np.arange(8000)[m]  # correctly classified images

# original (unnormalized) test images
x_test = x_test[:8000]

# plot first 10 false classifications
for i in i0[0:10]:
    plot_prediction(x_test[i], y_test_onehot[i], y_predict[i])

# plot first 10 correct classifications
for i in i1[0:10]:
    plot_prediction(x_test[i], y_test_onehot[i], y_predict[i])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
